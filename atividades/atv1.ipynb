# %% [markdown]
# Serie com o indice de dengue por região do país
# Região || Número de casos (Dados de 2023)

# %%
#importando as bibliotecas
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
#dicionário com os dados
dengue_por_regiao = {
    'Sudeste': 37.243,
    'Centro-Oeste': 13.806,
    'Nordeste': 6.287,
    'Norte': 6.287,
    'Sul': 2.482 
}

# %%
#convertendo para serie
table = pd.Series(dengue_por_regiao)
table
# Out:
# Sudeste         37.243
# Centro-Oeste    13.806
# Nordeste         6.287
# Norte            6.287
# Sul              2.482
# dtype: float64

# %%
#gráfico com o método plot da biblioteca matplotlib
table.plot()
# Out:
# <Axes: >
